# %%
# Data Visualization: Beyond Matplotlib

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
tips = sns.load_dataset("tips")
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# Gemerating a line plot using Seaborn 

sns.lineplot(data=tips, # choose our dataset
x='total_bill', # define our x variable
y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Applying Styles 
sns.set_style('darkgrid')

# Gemerating a line plot using Seaborn 

sns.lineplot(data=tips, # choose our dataset
x='total_bill', # define our x variable
y='tip') # define our y variable
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Modify size of plot 
fig = plt.subplots(figsize=(10, 3))

# Add title and axis labels

tipgraph = sns.lineplot(data=tips,
x='total_bill',
y='tip')
tipgraph.set(title='Tips vs. Total Bill',
xlabel='Total Bill ($)',
ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
# Modify Aesthetics 

tipgraph = sns.lineplot(data=tips,
x='total_bill',
y='tip',
color = 'hotpink',
linestyle = '--',
linewidth = 3,
marker = 'o',
markerfacecolor = 'indigo')

# %%
# Multiple Variables 

tipgraph = sns.scatterplot(data=tips, x='total_bill',
                           y='tip', 
                           style = 'time', 
                           hue = 'day', 
                           palette = ['purple', 'hotpink', 'deepskyblue', 'yellowgreen']
                           )
tipgraph.set(title='Tips vs. Total Bill',
xlabel='Total Bill ($)',
ylabel='Tip Amount ($)')
# Out:
# [Text(0.5, 1.0, 'Tips vs. Total Bill'),
#  Text(0.5, 0, 'Total Bill ($)'),
#  Text(0, 0.5, 'Tip Amount ($)')]

# %%
# Pair Plots 
# For all numerical variables 

sns.pairplot(data = tips,
             hue = 'day'
             )

# %%
# RelPlot 

daysplot = sns.relplot(
    data=tips,
    x="total_bill",
    y="tip",
    hue="sex",
    col="day",
    kind="scatter",
    col_wrap=3
    )


# Replot divide the canvas to multiple subplots, based on value of col_wrap. 
# It will then scatter plot separately for different days and will color based on sex.

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.23.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting tenacity>=6.2.0 (from plotly)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from plotly) (23.2)
# Downloading plotly-5.23.0-py3-none-any.whl (17.3 MB)
#    ---------------------------------------- 0.0/17.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/17.3 MB 217.9 kB/s eta 0:01:20
#    ---------------------------------------- 0.1/17.3 MB 544.7 kB/s eta 0:00:32
#    ---------------------------------------- 0.1/17.3 MB 944.1 kB/s eta 0:00:19
#     --------------------------------------- 0.3/17.3 MB 1.5 MB/s eta 0:00:12
#    - -------------------------------------- 0.4/17.3 MB 1.8 MB/s eta 0:00:10
#    - -------------------------------------- 0.7/17.3 MB 2.4 MB/s eta 0:00:07
#    -- ------------------------------------- 1.0/17.3 MB 2.8 MB/s eta 0:00:06
#    -- ------------------------------------- 1.2/17.3 MB 3.1 MB/s eta 0:00:06
#    --- ------------------------------------ 1.4/17.3 MB 3.2 MB/s eta 0:00:05
#    --- ------------------------------------ 1.6/17.3 MB 3.3 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.9/17.3 MB 3.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 2.1/17.3 MB 3.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 2.4/17.3 MB 3.9 MB/s eta 0:00:04
#    ------ --------------------------------- 2.7/17.3 MB 4.1 MB/s eta 0:00:04
#    ------ --------------------------------- 3.0/17.3 MB 4.1 MB/s eta 0:00:04
#    ------- -------------------------------- 3.1/17.3 MB 4.1 MB/s eta 0:00:04
#    ------- -------------------------------- 3.4/17.3 MB 4.2 MB/s eta 0:00:04
#    -------- ------------------------------- 3.6/17.3 MB 4.2 MB/s eta 0:00:04
#    -------- ------------------------------- 3.9/17.3 MB 4.3 MB/s eta 0:00:04
#    --------- ------------------------------ 4.0/17.3 MB 4.2 MB/s eta 0:00:04
#    --------- ------------------------------ 4.3/17.3 MB 4.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.5/17.3 MB 4.3 MB/s eta 0:00:04
#    ---------- ----------------------------- 4.7/17.3 MB 4.3 MB/s eta 0:00:03
#    ----------- ---------------------------- 4.9/17.3 MB 4.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 5.2/17.3 MB 4.3 MB/s eta 0:00:03
#    ------------ --------------------------- 5.2/17.3 MB 4.2 MB/s eta 0:00:03
#    ------------ --------------------------- 5.4/17.3 MB 4.2 MB/s eta 0:00:03
#    ------------ --------------------------- 5.5/17.3 MB 4.1 MB/s eta 0:00:03
#    ------------- -------------------------- 5.8/17.3 MB 4.2 MB/s eta 0:00:03
#    ------------- -------------------------- 6.1/17.3 MB 4.3 MB/s eta 0:00:03
#    -------------- ------------------------- 6.3/17.3 MB 4.3 MB/s eta 0:00:03
#    -------------- ------------------------- 6.5/17.3 MB 4.3 MB/s eta 0:00:03
#    --------------- ------------------------ 6.7/17.3 MB 4.3 MB/s eta 0:00:03
#    --------------- ------------------------ 6.9/17.3 MB 4.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 7.2/17.3 MB 4.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.5/17.3 MB 4.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 7.8/17.3 MB 4.4 MB/s eta 0:00:03
#    ------------------ --------------------- 8.1/17.3 MB 4.5 MB/s eta 0:00:03
#    ------------------- -------------------- 8.3/17.3 MB 4.5 MB/s eta 0:00:02
#    ------------------- -------------------- 8.6/17.3 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 8.8/17.3 MB 4.5 MB/s eta 0:00:02
#    -------------------- ------------------- 8.9/17.3 MB 4.5 MB/s eta 0:00:02
#    --------------------- ------------------ 9.2/17.3 MB 4.5 MB/s eta 0:00:02
#    --------------------- ------------------ 9.4/17.3 MB 4.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 9.8/17.3 MB 4.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 10.1/17.3 MB 4.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 10.3/17.3 MB 4.7 MB/s eta 0:00:02
#    ------------------------ --------------- 10.4/17.3 MB 4.8 MB/s eta 0:00:02
#    ------------------------ --------------- 10.7/17.3 MB 4.9 MB/s eta 0:00:02
#    ------------------------- -------------- 10.9/17.3 MB 4.9 MB/s eta 0:00:02
#    ------------------------- -------------- 11.1/17.3 MB 4.9 MB/s eta 0:00:02
#    -------------------------- ------------- 11.3/17.3 MB 4.9 MB/s eta 0:00:02
#    -------------------------- ------------- 11.6/17.3 MB 4.9 MB/s eta 0:00:02
#    --------------------------- ------------ 11.8/17.3 MB 5.0 MB/s eta 0:00:02
#    --------------------------- ------------ 12.0/17.3 MB 4.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 12.3/17.3 MB 4.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 12.6/17.3 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.9/17.3 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 12.9/17.3 MB 4.9 MB/s eta 0:00:01
#    ------------------------------ --------- 13.0/17.3 MB 4.8 MB/s eta 0:00:01
#    ------------------------------ --------- 13.3/17.3 MB 4.7 MB/s eta 0:00:01
#    ------------------------------- -------- 13.4/17.3 MB 4.8 MB/s eta 0:00:01
#    ------------------------------- -------- 13.7/17.3 MB 4.8 MB/s eta 0:00:01
#    -------------------------------- ------- 13.9/17.3 MB 4.7 MB/s eta 0:00:01
#    -------------------------------- ------- 14.2/17.3 MB 4.8 MB/s eta 0:00:01
#    --------------------------------- ------ 14.6/17.3 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.9/17.3 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 15.1/17.3 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 15.4/17.3 MB 5.0 MB/s eta 0:00:01
#    ------------------------------------ --- 15.7/17.3 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------ --- 15.9/17.3 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 16.3/17.3 MB 5.1 MB/s eta 0:00:01
#    -------------------------------------- - 16.5/17.3 MB 5.2 MB/s eta 0:00:01
#    -------------------------------------- - 16.7/17.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  17.0/17.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  17.2/17.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------  17.3/17.3 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 17.3/17.3 MB 5.0 MB/s eta 0:00:00
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.23.0 tenacity-9.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# PLOTLY 

import plotly.graph_objects as go # 'go' is 'graph objects’
x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

# %%
graph = go.Figure()
graph.add_trace(go.Bar(x=x1, y=y1))

graph.update_layout(
    title="Pirate Scores",
    xaxis_title="Pirates",
    yaxis_title="Score"
    )

graph.show()

# %%
# Saving as html 

graph.write_html("pirategraph.html")

# %%
# Customization 

graph = go.Figure()
graph.add_trace(
    go.Scatter(
        x=x1, y=y1, mode='markers', # we want points for a scatter plot
        marker=dict(
            size=15, # point size
            color='hotpink', # point colour
            opacity=1, # point transparency/alpha
            line=dict(width=5, color='purple') # point outline
            )
        )
    )
graph.update_layout(
    title='Interactive Pirate Plot',
    xaxis_title='Pirates',
    yaxis_title='Scores',
    width=500, height=500
    )

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: pillow in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from wordcloud) (10.3.0)
# Requirement already satisfied: matplotlib in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from wordcloud) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->wordcloud) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp39-cp39-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.6 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/300.6 kB 326.8 kB/s eta 0:00:01
#    ------------------------- -------------- 194.6/300.6 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 300.6/300.6 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %%
# WordCloud 

from wordcloud import WordCloud
df = pd.read_csv("https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
    on_bad_lines='skip')
df
# Out:
#                                                  quote  \
# 0                      Do, or do not. There is no try.
# 1    Listen to them. Children of the night. What mu...
# 2                              It's alive! It's alive!
# 3    Oh, no, it wasn't the airplanes. It was Beauty...
# 4    Magic Mirror on the wall, who is the fairest o...
# ..                                                 ...
# 727  I didn't know if you were lost. Stick with me....
# 728  This guy's awesome! He's holding his own while...
# 729     Murder is murder, it don’t matter who you are.
# 730  You know what a lion is? A lion is a strong an...
# 731  That was the best acting i've ever seen in my ...
#
#                                               movie   type  year
# 0    Star Wars: Episode V - The Empire Strikes Back  movie  1890
# 1                                           Dracula  movie  1931
# 2                                      Frankenstein  movie  1931
# 3                                         King Kong  movie  1933
# 4                  Snow White and the Seven Dwarves  movie  1937
# ..                                              ...    ...   ...
# 727                                              Us  movie  2019
# 728                        Dragon Ball Super: Broly  movie  2019
# 729                                  Black and Blue  movie  2019
# 730                    Between Two Ferns: The Movie  movie  2019
# 731                   Once Upon a Time in Hollywood  movie  2019
#
# [732 rows x 4 columns]

# %%
# join all our text from each row from our quote column into a string
text = " ".join(each for each in df.quote)
# generate our wordcloud image
wordcloud = WordCloud(background_color="white",
    colormap = 'inferno').generate(text)
# use matplotlib syntax to put our image in a figure
fig, ax = plt.subplots(figsize=(7, 3))
ax.imshow(wordcloud, 
interpolation='bilinear') # this line helps smooth our image
ax.axis("off")
plt.show()

# %%
pip install matplotlib_venn
# Out:
# Collecting matplotlib_venn
#   Downloading matplotlib-venn-1.1.1.tar.gz (40 kB)
#      ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#      ---------- ----------------------------- 10.2/40.3 kB ? eta -:--:--
#      ------------------- ------------------ 20.5/40.3 kB 165.2 kB/s eta 0:00:01
#      -------------------------------------- 40.3/40.3 kB 240.3 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib_venn) (3.9.0)
# Requirement already satisfied: numpy in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib_venn) (1.24.4)
# Requirement already satisfied: scipy in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib_venn) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (4.52.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from matplotlib->matplotlib_venn) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->matplotlib_venn) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\engr_\.conda\envs\dsi_participant\lib\site-packages (from python-dateutil>=2.7->matplotlib->matplotlib_venn) (1.16.0)
# Building wheels for collected packages: matplotlib_venn
#   Building wheel for matplotlib_venn (pyproject.toml): started
#   Building wheel for matplotlib_venn (pyproject.toml): finished with status 'done'
#   Created wheel for matplotlib_venn: filename=matplotlib_venn-1.1.1-py3-none-any.whl size=45335 sha256=9dcbdcbe08baf93d2d87e69793c227679b63d4eda2e8c8abb193ca60c8d5f27d
#   Stored in directory: c:\users\engr_\appdata\local\pip\cache\wheels\5c\4b\48\d68a6531b1e1e7411520ab9f395994eb1ee2ffafd6837b7f6c
# Successfully built matplotlib_venn
# Installing collected packages: matplotlib_venn
# Successfully installed matplotlib_venn-1.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Venn Diagrams

from matplotlib_venn import venn2, venn2_circles, venn2_unweighted

A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])

diagram = venn2_unweighted([A, B],
    set_labels = ('Fruits', 'Pies'),
    set_colors=("blue", "red"),
    alpha=0.5
    )
plt.show()
46
# Out:
# c:\Users\engr_\.conda\envs\dsi_participant\lib\site-packages\matplotlib_venn\_util.py:32: UserWarning:
#
# venn2_unweighted is deprecated. Use venn2 with the appropriate layout_algorithm instead.
# 46

# %%
# Adding Text 

diagram = venn2_unweighted([A, B],
    set_labels = ('Fruits', 'Pies'),
    set_colors=("blue", "red"),
    alpha=0.5
    )


diagram.get_label_by_id("10").set_text("n".join(A - B))
diagram.get_label_by_id("11").set_text("n".join(A & B))
diagram.get_label_by_id("01").set_text("n".join(B - A))
